# %% [markdown]
# # 🎬 YouTube Report Generator - Web Demo
#
# **LLM 기반 YouTube 영상 분석 리포트 생성기**
#
# ---
#
# ### 📌 About This Demo
#
# 이 웹 데모는 YouTube 영상의 **메타데이터, 요약, 댓글 반응 분석**을 LLM으로 자동 생성합니다.
#  - **LLM Model**  Llama 3.1-8B-Instruct (4-bit quantized)
#  - **Base Code**  Git 제출 `pipeline.ipynb` 기반
#  - **Web Demo Made by**  Claude Opus (Anthropic)
#
# ---
#
# ### ⚠️ Note
#
# - **Category / Sentiment 모델 제외**: 모델 용량 및 구현 복잡도를 고려하여,
#   별도의 분류/감성 모델 import 없이 **순수 LLM만으로** 분석을 수행합니다.
#   import된 결과 확인은 `pipeline.ipynb' 참조
# - 카테고리 분류와 감성 분석은 LLM의 프롬프트 기반 추론만 제공됩니다.
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/sdouf5054/20252R0136COSE36203.git
# %cd /content/drive/MyDrive/20252R0136COSE36203/youtube_report_webapp_colab
# Out:
# /content/drive/MyDrive
# fatal: destination path '20252R0136COSE36203' already exists and is not an empty directory.
# /content/drive/MyDrive/20252R0136COSE36203/youtube_report_webapp_colab

# %%
# !pip install -r requirements.txt

# 혹시 누락되었을 수도 있는 패키지 (이미 requirements에 있으면 재설치만 됨)
# !pip install gradio transformers accelerate bitsandbytes google-api-python-client isodate langdetect
# Out:
# ...
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 155.6 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=e3d063cbd25d196a80892eeb43430e1d0986560056036190c11e53deb0406d05
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %%
# 모델 변경 (default : llama3.1-8b)
from pipeline import PipelineConfig, list_available_models

# 사용 가능한 모델 목록 보기
list_available_models()

# 프리셋으로 Config 생성
# config = PipelineConfig.from_preset('mistral-7b')   # 영어 추천
# config = PipelineConfig.from_preset('qwen2.5-7b')   # 한국어 추천
# config = PipelineConfig.from_preset('phi3-mini')    # 가벼운 모델
# Out:
# ...
# 📦 Available Model Presets
# ...
#
# 🟢 No Approval Required (바로 사용 가능):
#
#   'mistral-7b'
#       Mistral 7B Instruct v0.3 - 빠르고 품질 좋음 (추천)
#       VRAM: ~5.0GB | 4-bit: True
#
#   'qwen2.5-7b'
#       Qwen 2.5 7B - 다국어 지원 우수 (한국어 추천)
#       VRAM: ~5.0GB | 4-bit: True
#
#   'gemma2-9b'
#       Google Gemma 2 9B - 고품질, 약간 느림
#       VRAM: ~6.0GB | 4-bit: True
#
#   'phi3-mini'
#       Microsoft Phi-3 Mini 3.8B - 가볍고 빠름
#       VRAM: ~3.0GB | 4-bit: True
#
#   'phi3.5-mini'
#       Microsoft Phi-3.5 Mini - 최신, 성능 개선
#       VRAM: ~3.5GB | 4-bit: True
#
#   'tinyllama'
#       TinyLlama 1.1B - 매우 가벼움, 품질 낮음
#       VRAM: ~2.5GB | 4-bit: False
#
#   'stablelm-2'
#       StableLM 2 1.6B - 가볍고 안정적
#       VRAM: ~3.0GB | 4-bit: False
#
# 🟡 Requires HF Approval (승인 필요):
#
#   'llama3.1-8b'
#       Llama 3.1 8B - 최고 품질 (HF 승인 필요)
#
#   'llama3.2-3b'
#       Llama 3.2 3B - 가벼운 Llama (HF 승인 필요)
#
# ...
# Usage: config = PipelineConfig.from_preset('mistral-7b')
# ...

# %%
import os
# ESSENTIAL
# Set your YouTube API key (get from https://console.developers.google.com)
os.environ['YOUTUBE_API_KEY'] = ''

# If model need hugging face token auth for model usage approval
# EX) meta-llama/Llama-3.1-8B-Instruct (defalut in fact..)
os.environ["HUGGING_FACE_HUB_TOKEN"] = ""

# %%
# !python app_gradio.py
# Out:
# 2025-12-13 04:54:32.968406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765601672.989246    2556 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765601672.995561    2556 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765601673.011368    2556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
